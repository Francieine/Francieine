# %% [markdown]
# <a href="https://colab.research.google.com/github/Francieine/Francieine/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Praticando python para criação de IA (ML) - Passo a passo Copilot
#1º Passo: instalar pacotes tensorflow (framework?)
#2º Passo: Carregar DataSet
#3º Passo: Pré-processar os dados
#4º Passo: Criar o modelo
#5º Passo: Compilar e treinar
#6º Passo: Testar previsões

# %%
# !pip install tensorflow

# %%
from tensorflow.keras.datasets import mnist

# Carregar dados
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("Formato do treino:", x_train.shape)
print("Formato do teste:", x_test.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Formato do treino: (60000, 28, 28)
# Formato do teste: (10000, 28, 28)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([
    Flatten(input_shape=(28,28)),   # transforma 28x28 em vetor
    Dense(128, activation='relu'),  # camada oculta
    Dense(10, activation='softmax') # saída: 10 classes (0–9)
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8753 - loss: 0.4345 - val_accuracy: 0.9620 - val_loss: 0.1270
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9676 - loss: 0.1124 - val_accuracy: 0.9724 - val_loss: 0.0968
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9780 - loss: 0.0731 - val_accuracy: 0.9745 - val_loss: 0.0824
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9847 - loss: 0.0528 - val_accuracy: 0.9771 - val_loss: 0.0763
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9870 - loss: 0.0423 - val_accuracy: 0.9773 - val_loss: 0.0751

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.imshow(x_test[0], cmap='gray')
pred = model.predict(x_test[0].reshape(1,28,28))
print("Classe prevista:", np.argmax(pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Classe prevista: 7

# %%
import matplotlib.pyplot as plt

# Mostrar as 9 primeiras imagens do conjunto de treino
plt.figure(figsize=(8,8))
for i in range(9):
    plt.subplot(3,3,i+1)   # cria uma grade 3x3
    plt.imshow(x_train[i], cmap='gray')  # exibe em escala de cinza
    plt.title(f"Label: {y_train[i]}")    # mostra o número real (rótulo)
    plt.axis('off')
plt.show()
